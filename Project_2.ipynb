# %% [markdown]
# # Project 2

# %% [markdown]
# In this project, I compare the *Foreign Direct Investment* and *GDP* data from the World Bank Group.
#
# My assumption is that ***for a certain country, as the Foreign Direct Ivestment grows, the domestic capital stack increases, leading to an increase in GDP***.
#
# However, it is not sure that by 1 percent of the FDI growth, how much percentage of the GDP growth will be shown.

# %% [markdown]
# # Key Concepts:
#
# Foreign Direct Investment (FDI):
#
# > FDI refers to an investment made by an entity from one country into a business or asset in another country, with the intention of establishing a lasting interest and significant control.
#
# Key aspects of FDI include:
#
# > - It typically involves ownership of at least 10% of the voting rights in the foreign enterprise.
# > - FDI goes beyond mere capital investment, often including the provision of management, technology, and equipment.
# > - It can take various forms, such as establishing new facilities, acquiring existing businesses, or expanding operations in a foreign country.
#
# FDI does not have a specific formula, but it is measured as the value of cross-border transactions related to direct investment over time. It includes:
# - Equity transactions
# - Reinvestment of earnings
# - Intercompany debt transactions
#
# Gross Domestic Product (GDP):
#
# > GDP is the total monetary or market value of all finished goods and services produced within a country's borders during a specific time period, typically a year or quarter. GDP serves as a comprehensive measure of a country's economic health.
#
# Important features of GDP include:
# > - It encompasses all private and public consumption, government expenditures, investments, and net exports (exports minus imports).
# > - GDP can be calculated using three methods: expenditure, production, or income approaches.
# >- It can be expressed in nominal terms (current prices) or real terms (adjusted for inflation)

# %% [markdown]
# Import Data from World Bank

# %%
import pandas as pd
file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')
print(wb_fdi.head())
print(wb_fdi.info())
# Out:
#          Series Name  Series Code    Country Name Country Code 2000 [YR2000]  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG      19542982
# 1  Population, total  SP.POP.TOTL         Albania          ALB       3089027
# 2  Population, total  SP.POP.TOTL         Algeria          DZA      30774621
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM         58230
# 4  Population, total  SP.POP.TOTL         Andorra          AND         66097
#
#   2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  ...  \
# 0      19688632      21000256      22645130      23553551      24411191  ...
# 1       3060173       3051010       3039616       3026939       3011487  ...
# 2      31200985      31624696      32055883      32510186      32956690  ...
# 3         58324         58177         57941         57626         57254  ...
# 4         67820         70849         73907         76933         79826  ...
#
# ...

# %% [markdown]
# # FDI Overview for Five Countries: China, U.S., UK, Japan, Ukraine

# %% [markdown]
# China's Case

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'China'

# Filter using the exact series name
fdi_data = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_data = fdi_data[fdi_data['Country Name'] == country_name]

if country_name not in wb_fdi['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No FDI data available for {country_name}.")
else:
    years = country_data.columns[4:]
    fdi_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, fdi_values/1e9, marker='o', linestyle='-')  # Convert to billions for better readability
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('FDI Inflow (Billions USD)')
plt.title(f'FDI Inflow Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# United State's case

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'United States'

# Filter using the exact series name
fdi_data = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_data = fdi_data[fdi_data['Country Name'] == country_name]

if country_name not in wb_fdi['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No FDI data available for {country_name}.")
else:
    years = country_data.columns[4:]
    fdi_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, fdi_values/1e9, marker='o', linestyle='-')  # Convert to billions for better readability
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('FDI Inflow (Billions USD)')
plt.title(f'FDI Inflow Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# United Kingdom's case

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'United Kingdom'

# Filter using the exact series name
fdi_data = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_data = fdi_data[fdi_data['Country Name'] == country_name]

if country_name not in wb_fdi['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No FDI data available for {country_name}.")
else:
    years = country_data.columns[4:]
    # Ensure proper numeric conversion
    fdi_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, fdi_values/1e9, marker='o', linestyle='-')  # Convert to billions for better readability
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('FDI Inflow (Billions USD)')
plt.title(f'FDI Inflow Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Japan's case

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'Japan'

# Filter using the exact series name
fdi_data = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_data = fdi_data[fdi_data['Country Name'] == country_name]

if country_name not in wb_fdi['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No FDI data available for {country_name}.")
else:
    years = country_data.columns[4:]
    fdi_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, fdi_values/1e9, marker='o', linestyle='-')  # Convert to billions for better readability
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('FDI Inflow (Billions USD)')
plt.title(f'FDI Inflow Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'Ukraine'

# Filter using the exact series name
fdi_data = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_data = fdi_data[fdi_data['Country Name'] == country_name]

if country_name not in wb_fdi['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No FDI data available for {country_name}.")
else:
    years = country_data.columns[4:]
    fdi_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, fdi_values/1e9, marker='o', linestyle='-')  # Convert to billions for better readability
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('FDI Inflow (Billions USD)')
plt.title(f'FDI Inflow Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # GDP Overview for Five Countries: China, U.S., UK, Japan, Ukraine

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_data = pd.read_csv(file_path, encoding='utf-8')

country_name = 'China'

# Filter using the exact series name
gdp_data = wb_data[wb_data['Series Name'] == 'GDP (current US$)']
country_data = gdp_data[gdp_data['Country Name'] == country_name]

if country_name not in gdp_data['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No GDP data available for {country_name}.")
else:
    years = country_data.columns[4:]
    gdp_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, gdp_values, marker='o', linestyle='-')  # Use the variables directly
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('GDP (current USD$ in billion)')
plt.title(f'GDP Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_data = pd.read_csv(file_path, encoding='utf-8')

country_name = 'United States'

# Filter using the exact series name
gdp_data = wb_data[wb_data['Series Name'] == 'GDP (current US$)']
country_data = gdp_data[gdp_data['Country Name'] == country_name]

if country_name not in gdp_data['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No GDP data available for {country_name}.")
else:
    years = country_data.columns[4:]
    gdp_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, gdp_values, marker='o', linestyle='-')  # Use the variables directly
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('GDP (current USD$ in billion)')
plt.title(f'GDP Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_data = pd.read_csv(file_path, encoding='utf-8')

country_name = 'United Kingdom'

# Filter using the exact series name
gdp_data = wb_data[wb_data['Series Name'] == 'GDP (current US$)']
country_data = gdp_data[gdp_data['Country Name'] == country_name]

if country_name not in gdp_data['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No GDP data available for {country_name}.")
else:
    years = country_data.columns[4:]
    gdp_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, gdp_values, marker='o', linestyle='-')  # Use the variables directly
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('GDP (current USD$ in billion)')
plt.title(f'GDP Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_data = pd.read_csv(file_path, encoding='utf-8')

country_name = 'Japan'

# Filter using the exact series name
gdp_data = wb_data[wb_data['Series Name'] == 'GDP (current US$)']
country_data = gdp_data[gdp_data['Country Name'] == country_name]

if country_name not in gdp_data['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No GDP data available for {country_name}.")
else:
    years = country_data.columns[4:]
    gdp_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, gdp_values, marker='o', linestyle='-')  # Use the variables directly
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('GDP (current USD$ in billion)')
plt.title(f'GDP Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_data = pd.read_csv(file_path, encoding='utf-8')

country_name = 'Ukraine'

# Filter using the exact series name
gdp_data = wb_data[wb_data['Series Name'] == 'GDP (current US$)']
country_data = gdp_data[gdp_data['Country Name'] == country_name]

if country_name not in gdp_data['Country Name'].values:
    print(f"Error: {country_name} not found in the dataset.")
elif country_data.empty:
    print(f"No GDP data available for {country_name}.")
else:
    years = country_data.columns[4:]
    gdp_values = pd.to_numeric(country_data.iloc[0, 4:].values, errors='coerce')

# Create the plot with proper scaling
plt.figure(figsize=(10, 5))
plt.plot(years, gdp_values, marker='o', linestyle='-')  # Use the variables directly
plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)  # Add a horizontal line at y=0
plt.grid(True, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('GDP (current USD$)')
plt.title(f'GDP Over Years for {country_name}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Correlation between GDP and FDI for Five Countries: China, U.S., UK, Japan, Ukraine

# %%
import pandas as pd
import matplotlib.pyplot as plt

country_name = 'China'

# Filter using the exact series name
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDPcurrent US$)']
country_fdi = fdi_data[fdi_data['Country Name'] == country_name]
country_gdp = gdp_data[gdp_data['Country Name'] == country_name]

# Extract numerical values for the years
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(8, 6))
plt.scatter(fdi_values, gdp_values, color='blue', alpha=0.7)

# Calculate correlation
correlation = np.corrcoef(fdi_values, gdp_values)[0, 1]
plt.title(f"Correlation for FDI and GDP for {country_name}, Correlation: {correlation:.2f}")

# Add labels and grid
plt.xlabel('FDI (current US$)')
plt.ylabel('GDP (current US$)')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

country_name = 'United States'

# Filter using the exact series name
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = fdi_data[fdi_data['Country Name'] == country_name]
country_gdp = gdp_data[gdp_data['Country Name'] == country_name]

# Extract numerical values for the years
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(8, 6))
plt.scatter(fdi_values, gdp_values, color='blue', alpha=0.7)

# Calculate correlation
correlation = np.corrcoef(fdi_values, gdp_values)[0, 1]
plt.title(f"Correlation for FDI and GDP for {country_name}, Correlation: {correlation:.2f}")

# Add labels and grid
plt.xlabel('FDI (current US$)')
plt.ylabel('GDP (current US$)')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

country_name = 'United Kingdom'

# Filter using the exact series name
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = fdi_data[fdi_data['Country Name'] == country_name]
country_gdp = gdp_data[gdp_data['Country Name'] == country_name]

# Extract numerical values for the years
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(8, 6))
plt.scatter(fdi_values, gdp_values, color='blue', alpha=0.7)

# Calculate correlation
correlation = np.corrcoef(fdi_values, gdp_values)[0, 1]
plt.title(f"Correlation for FDI and GDP for {country_name}, Correlation: {correlation:.2f}")

# Add labels and grid
plt.xlabel('FDI (current US$)')
plt.ylabel('GDP (current US$)')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

country_name = 'Japan'

# Filter using the exact series name
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = fdi_data[fdi_data['Country Name'] == country_name]
country_gdp = gdp_data[gdp_data['Country Name'] == country_name]

# Extract numerical values for the years
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(8, 6))
plt.scatter(fdi_values, gdp_values, color='blue', alpha=0.7)

# Calculate correlation
correlation = np.corrcoef(fdi_values, gdp_values)[0, 1]
plt.title(f"Correlation for FDI and GDP for {country_name}, Correlation: {correlation:.2f}")

# Add labels and grid
plt.xlabel('FDI (current US$)')
plt.ylabel('GDP (current US$)')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

country_name = 'Ukraine'

# Filter using the exact series name
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = fdi_data[fdi_data['Country Name'] == country_name]
country_gdp = gdp_data[gdp_data['Country Name'] == country_name]

# Extract numerical values for the years
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(8, 6))
plt.scatter(fdi_values, gdp_values, color='blue', alpha=0.7)

# Calculate correlation
correlation = np.corrcoef(fdi_values, gdp_values)[0, 1]
plt.title(f"Correlation for FDI and GDP for {country_name}, Correlation: {correlation:.2f}")

# Add labels and grid
plt.xlabel('FDI (current US$)')
plt.ylabel('GDP (current US$)')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'China'

# Filter the data for GDP and FDI
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = country_fdi[country_fdi['Country Name'] == country_name]
country_gdp = country_gdp[country_gdp['Country Name'] == country_name]

# Extract years and values
years = country_fdi.columns[4:]  # Get year columns
years = [year[:4] for year in years]  # Extract only the first 4 digits
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(40, 10))
plt.plot(years, gdp_values, label="GDP", marker='o', color='blue', markersize=30)
plt.plot(years, fdi_values, label="FDI", marker='D', color='red', markersize=30)

# Add titles and axis labels
plt.title(f'GDP and FDI Over Years for {country_name}', fontsize=30)
plt.xlabel("Years", fontsize=30)
plt.ylabel("USD (in billion)", fontsize=30)

# Adjust tick label sizes for both axes
plt.xticks(fontsize=20)  # X-axis tick labels
plt.yticks(fontsize=20)  # Y-axis tick labels

# Add legend and grid
plt.legend(fontsize=30, loc='upper left') 
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'United States'

# Filter the data for GDP and FDI
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = country_fdi[country_fdi['Country Name'] == country_name]
country_gdp = country_gdp[country_gdp['Country Name'] == country_name]

# Extract years and values
years = country_fdi.columns[4:]  # Get year columns
years = [year[:4] for year in years]  # Extract only the first 4 digits
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(40, 10))
plt.plot(years, gdp_values, label="GDP", marker='o', color='blue', markersize=30)
plt.plot(years, fdi_values, label="FDI", marker='D', color='red', markersize=30)

# Add titles and axis labels
plt.title(f'GDP and FDI Over Years for {country_name}', fontsize=30)
plt.xlabel("Years", fontsize=30)
plt.ylabel("USD (in billion)", fontsize=30)

# Adjust tick label sizes for both axes
plt.xticks(fontsize=20)  # X-axis tick labels
plt.yticks(fontsize=20)  # Y-axis tick labels

# Add legend and grid
plt.legend(fontsize=30, loc='upper left') 
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'United Kingdom'

# Filter the data for GDP and FDI
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = country_fdi[country_fdi['Country Name'] == country_name]
country_gdp = country_gdp[country_gdp['Country Name'] == country_name]

# Extract years and values
years = country_fdi.columns[4:]  # Get year columns
years = [year[:4] for year in years]  # Extract only the first 4 digits
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(40, 10))
plt.plot(years, gdp_values, label="GDP", marker='o', color='blue', markersize=30)
plt.plot(years, fdi_values, label="FDI", marker='D', color='red', markersize=30)

# Add titles and axis labels
plt.title(f'GDP and FDI Over Years for {country_name}', fontsize=30)
plt.xlabel("Years", fontsize=30)
plt.ylabel("USD (in billion)", fontsize=30)

# Adjust tick label sizes for both axes
plt.xticks(fontsize=20)  # X-axis tick labels
plt.yticks(fontsize=20)  # Y-axis tick labels

# Add legend and grid
plt.legend(fontsize=30, loc='upper left') 
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'Japan'

# Filter the data for GDP and FDI
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = country_fdi[country_fdi['Country Name'] == country_name]
country_gdp = country_gdp[country_gdp['Country Name'] == country_name]

# Extract years and values
years = country_fdi.columns[4:]  # Get year columns
years = [year[:4] for year in years]  # Extract only the first 4 digits
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(40, 10))
plt.plot(years, gdp_values, label="GDP", marker='o', color='blue', markersize=30)
plt.plot(years, fdi_values, label="FDI", marker='D', color='red', markersize=30)

# Add titles and axis labels
plt.title(f'GDP and FDI Over Years for {country_name}', fontsize=30)
plt.xlabel("Years", fontsize=30)
plt.ylabel("USD (in billion)", fontsize=30)

# Adjust tick label sizes for both axes
plt.xticks(fontsize=20)  # X-axis tick labels
plt.yticks(fontsize=20)  # Y-axis tick labels

# Add legend and grid
plt.legend(fontsize=30, loc='upper left') 
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/Users/User/Desktop/P_Popular Indicators (1)/6e33f2ce-9670-4af8-94be-742822d18827_Data.csv'
wb_fdi = pd.read_csv(file_path, encoding='utf-8')

country_name = 'Ukraine'

# Filter the data for GDP and FDI
country_fdi = wb_fdi[wb_fdi['Series Name'] == 'Foreign direct investment, net inflows (BoP, current US$)']
country_gdp = wb_fdi[wb_fdi['Series Name'] == 'GDP (current US$)']
country_fdi = country_fdi[country_fdi['Country Name'] == country_name]
country_gdp = country_gdp[country_gdp['Country Name'] == country_name]

# Extract years and values
years = country_fdi.columns[4:]  # Get year columns
years = [year[:4] for year in years]  # Extract only the first 4 digits
fdi_values = pd.to_numeric(country_fdi.iloc[0, 4:].values, errors='coerce')
gdp_values = pd.to_numeric(country_gdp.iloc[0, 4:].values, errors='coerce')

# Create the plot
plt.figure(figsize=(40, 10))
plt.plot(years, gdp_values, label="GDP", marker='o', color='blue', markersize=30)
plt.plot(years, fdi_values, label="FDI", marker='D', color='red', markersize=30)

# Add titles and axis labels
plt.title(f'GDP and FDI Over Years for {country_name}', fontsize=30)
plt.xlabel("Years", fontsize=30)
plt.ylabel("USD (in billion)", fontsize=30)

# Adjust tick label sizes for both axes
plt.xticks(fontsize=20)  # X-axis tick labels
plt.yticks(fontsize=20)  # Y-axis tick labels

# Add legend and grid
plt.legend(fontsize=30, loc='upper left') 
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# For five cases we investigate, three showed a positive relation between FDI and GDP. For China, U.S., and Ukraine, there are positive correlations proving our assumption correct (China: 0.56, U.S.: 0.51, Ukraine: 0.59). However, for case of U.K. and Japan, there shows a negative correlation (UK: -0.11, Japan: -0.18). The reasons require further investigation.
